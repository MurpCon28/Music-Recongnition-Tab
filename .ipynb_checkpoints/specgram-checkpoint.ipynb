# %%
import wave
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import signal
import seaborn as sns
from scipy.io import wavfile
import pylab
import matplotlib.mlab as ml
from scipy.fftpack import fft

# %matplotlib tk

# %%
DEFAULT_FS = 44100
DEFAULT_WINDOW_SIZE = 4096
DEFAULT_OVERLAP_RATIO = 0.5
DEFAULT_FAN_VALUE = 15
DEFAULT_AMP_MIN = 10

def graph_spectrogram(sound_info, frame_rate):
    pylab.figure(num=None, figsize=(19, 12))
    pylab.subplot(111)
    pylab.specgram(sound_info, Fs=frame_rate)
    pylab.savefig('spectrogram.png')

"""
Function that converts a byte string into a numpy array
"""
def _wav2array(nchannels, sampwidth, data):
    num_samples, remainder = divmod(len(data), sampwidth * nchannels)
    if remainder > 0:
        raise ValueError('The length of data is not a multiple of '
                         'sampwidth * num_channels.')
    if sampwidth > 4:
        raise ValueError("sampwidth must not be greater than 4.")

    if sampwidth == 3:
        a = np.empty((num_samples, nchannels, 4), dtype=np.uint8)
        raw_bytes = np.fromstring(data, dtype=np.uint8)
        a[:, :, :sampwidth] = raw_bytes.reshape(-1, nchannels, sampwidth)
        a[:, :, sampwidth:] = (a[:, :, sampwidth - 1:sampwidth] >> 7) * 255
        result = a.view('<i4').reshape(a.shape[:-1])
    else:
        dt_char = 'u' if sampwidth == 1 else 'i'
        a = np.fromstring(data, dtype='<%s%d' % (dt_char, sampwidth))
        result = a.reshape(-1, nchannels)
    return result

"""
Function to convert stereo to mono
"""

def stereo2mono(audiodata, nchannels):
#     if nchannels==1:
#         return audiodata.astype(int)
    audiodata = audiodata.astype(float)
    d = audiodata.sum(axis=1) / 2
    return d.astype(int)

"""
Class containing details of the wav file that has been read.
Sample use:
    song_x = song("abc.wav")
"""
class song:
    def __init__(self, file):
        wav = wave.open(file)
        self.title = file.split("/")[-1]
        self.rate = wav.getframerate()
        self.nchannels = wav.getnchannels()
        self.sampwidth = wav.getsampwidth()
        self.nframes = wav.getnframes()
        self.data = wav.readframes(self.nframes)
        self.array = stereo2mono(_wav2array(self.nchannels, self.sampwidth, self.data), self.nchannels)
        wav.close()
    def spectrogram(self):
        self.specgram, self.frequencies, self.times = ml.specgram(self.array, Fs=self.rate, NFFT = 8192, window = ml.window_hanning, noverlap = int(8192 * 0.5), mode='magnitude')
        self.specgram = 10*np.log10(self.specgram)
        self.specgram[self.specgram==-np.inf] = 0
#         self.specgram = (1/20)*(np.exp(self.specgram))
#         self.specgram[self.specgram<100000000000000000] = 100000000000000000
#         self.specgram[self.specgram>10000000000000000000] = 10000000000000000000
#         fig, ax = plt.subplots()
#         ax.imshow(self.specgram, aspect='auto')
#         ax.set_xlabel('Time')
#         ax.set_ylabel('Frequency')
#         ax.set_title("Spectrogram of "+self.title)
#         plt.gca().invert_yaxis()
#         plt.show()
    def find_key(self):
        self.spectrogram()
        all_times = self.specgram.transpose()
        bands = []
        for a in all_times:
            l = []
            x = max(a[0:10])
            l.append((x, list(a[0:10]).index(x)))
            x = max(a[10:20])
            l.append((x, list(a[10:20]).index(x)+10))
            x = max(a[20:40])
            l.append((x, list(a[20:40]).index(x)+20))
            x = max(a[40:80])
            l.append((x, list(a[40:80]).index(x)+40))
            x = max(a[80:160])
            l.append((x, list(a[80:160]).index(x)+80))
            x = max(a[160:510])
            l.append((x, list(a[160:510]).index(x)+160))
            bands.append(l)
        l = []
        for a in bands:
            for b in a:
                l.append(b[0])
        mean = 1.2*np.mean(l)
        new_bands = []
        for i in range(0, len(bands)):
            a = bands[i]
            m = [t[1] for t in a if t[0]>mean]
            if len(m)!=0:
                new_bands.append((i, m))
        self.bands = new_bands

# %%
total = song("Thin_Lizzy_-_Jailbreak.wav")
total = song("Foo_Fighters_-_Everlong.wav")
total = song("Pixies_-_Hey.wav")
total = song("The_Rolling_Stones_-_Monkey_Man.wav")
total = song("U2_-_City_Of_Blinding_Lights.wav")
#total = song("The_Beatles_-_Hey_Jude.wav")
#total = song("Dinosaur_Jr_-_I_Ran_Away.wav")
# Out:
# <ipython-input-2-e1343b106360>:32: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   a = np.fromstring(data, dtype='<%s%d' % (dt_char, sampwidth))

# %%
total.find_key()

# %%
from cmath import *
def fft(x, N):
    if N==1: 
        return x
    even = fft([x[k] for k in range(0,N,2)], int(N/2))
    odd = fft([x[k] for k in range(1,N,2)], int(N/2))
 
    M = int(N/2)
    l = [ even[k] + exp(-2j*pi*k/N)*odd[k] for k in range(M) ]
    r = [ even[k] - exp(-2j*pi*k/N)*odd[k] for k in range(M) ]
 
    return l+r

# %%
total.bands
# Out:
# [(4, [12]),
#  (13, [11]),
#  (20, [11]),
#  (41, [12]),
#  (53, [11, 34]),
#  (54, [34]),
#  (55, [34]),
#  (56, [33]),
#  (57, [34]),
#  (58, [34]),
#  (63, [34]),
#  (64, [33]),
#  (67, [11]),
#  (72, [34]),
#  (73, [34]),
#  (74, [38]),
#  (77, [34]),
#  (78, [34]),
#  (79, [12]),
#  (95, [11]),
#  (98, [42]),
#  (100, [33]),
#  (110, [34]),
#  (111, [34]),
#  (131, [34]),
#  (132, [34]),
#  (133, [34]),
#  (154, [38]),
#  (155, [38]),
#  (156, [38]),
#  (165, [11]),
#  (175, [12]),
#  (177, [37]),
#  (179, [11]),
#  (184, [12]),
#  (195, [32]),
#  (197, [33]),
#  (198, [16, 33]),
#  (207, [12]),
#  (208, [76]),
#  (212, [36]),
#  (213, [36, 72]),
#  (214, [34]),
#  (221, [101]),
#  (227, [75]),
#  (228, [12]),
#  (245, [34, 73]),
#  (246, [75]),
#  (248, [42]),
#  (251, [39]),
#  (252, [38]),
#  (258, [33]),
#  (259, [34]),
#  (261, [38]),
#  (262, [37]),
#  (263, [73]),
#  (265, [12]),
#  (276, [82]),
#  (277, [11]),
#  (284, [34]),
#  (288, [33]),
#  (291, [34]),
#  (292, [34]),
#  (296, [38, 77]),
#  (297, [77]),
#  (301, [38]),
#  (314, [11]),
#  (315, [76]),
#  (316, [38]),
#  (319, [37]),
#  (323, [12]),
#  (325, [37]),
#  (326, [38, 73]),
#  (327, [37]),
#  (330, [66]),
#  (331, [66]),
#  (332, [33, 65]),
#  (333, [65]),
#  (334, [66]),
#  (337, [19]),
#  (339, [18]),
#  (350, [85]),
#  (351, [11, 86]),
#  (361, [34]),
#  (362, [34]),
#  (365, [12]),
#  (372, [34]),
#  (377, [44]),
#  (387, [83]),
#  (388, [11]),
#  (389, [89]),
#  (390, [90]),
#  (408, [33]),
#  (409, [33]),
#  (411, [34]),
#  (412, [39]),
#  (425, [11]),
#  (426, [90]),
#  (427, [89]),
#  (430, [39]),
#  (433, [42]),
#  (434, [39]),
#  (436, [39]),
#  (438, [34]),
#  (439, [31]),
#  (443, [67]),
#  (452, [25]),
#  (453, [25]),
#  (455, [38]),
#  (462, [12]),
#  (471, [11]),
#  (472, [72]),
#  (473, [37, 72]),
#  (478, [37]),
#  (480, [12, 38, 76]),
#  (481, [38, 76]),
#  (482, [37]),
#  (487, [12]),
#  (498, [100]),
#  (501, [100]),
#  (502, [98]),
#  (503, [99]),
#  (504, [102]),
#  (505, [100]),
#  (508, [11]),
#  (517, [12]),
#  (519, [31]),
#  (524, [12]),
#  (526, [22]),
#  (527, [22]),
#  (534, [34]),
#  (535, [33]),
#  (538, [98]),
#  (539, [98]),
#  (540, [98]),
#  (541, [34, 102]),
#  (542, [102]),
#  (547, [38]),
#  (549, [11]),
#  (550, [73]),
#  (553, [85]),
#  (555, [84]),
#  (556, [82]),
#  (557, [77]),
#  (559, [28]),
#  (560, [64]),
#  (571, [22]),
#  (577, [34, 103]),
#  (578, [34]),
#  (583, [42]),
#  (593, [38]),
#  (596, [34]),
#  (597, [13]),
#  (599, [42]),
#  (600, [42]),
#  (603, [28]),
#  (604, [28]),
#  (605, [28]),
#  (607, [29]),
#  (609, [14, 28]),
#  (618, [12]),
#  (622, [14]),
#  (624, [42]),
#  (627, [11]),
#  (634, [12]),
#  (636, [22]),
#  (637, [22]),
#  (641, [98]),
#  (642, [22]),
#  (643, [101]),
#  (644, [23]),
#  (645, [22]),
#  (648, [101]),
#  (650, [96]),
#  (651, [100]),
#  (652, [100]),
#  (657, [38]),
#  (659, [11]),
#  (672, [22]),
#  (673, [22]),
#  (683, [98]),
#  (684, [99]),
#  (687, [103]),
#  (696, [76]),
#  (697, [75]),
#  (699, [85]),
#  (700, [85]),
#  (701, [84]),
#  (702, [83]),
#  (705, [65]),
#  (706, [66]),
#  (714, [34, 100]),
#  (715, [99]),
#  (716, [98]),
#  (717, [101]),
#  (718, [99]),
#  (719, [11]),
#  (725, [99]),
#  (726, [98]),
#  (732, [39, 40]),
#  (733, [38]),
#  (736, [84]),
#  (737, [11]),
#  (740, [39, 40]),
#  (742, [34]),
#  (744, [12]),
#  (746, [28]),
#  (748, [28]),
#  (749, [28]),
#  (757, [42]),
#  (764, [12]),
#  (768, [28]),
#  (771, [11]),
#  (773, [12]),
#  (774, [28]),
#  (776, [38]),
#  (780, [12]),
#  (789, [30]),
#  (793, [44, 88]),
#  (795, [41]),
#  (796, [40]),
#  (797, [34]),
#  (798, [34]),
#  (804, [31]),
#  (806, [33]),
#  (807, [32, 64]),
#  (808, [33]),
#  (809, [33, 66]),
#  (810, [33, 67]),
#  (815, [39]),
#  (817, [12]),
#  (833, [11]),
#  (838, [33]),
#  (840, [65]),
#  (841, [33]),
#  (843, [34]),
#  (854, [12, 32]),
#  (867, [34]),
#  (868, [34]),
#  (870, [11]),
#  (871, [75]),
#  (873, [86]),
#  (874, [84]),
#  (876, [77]),
#  (877, [76]),
#  (881, [67]),
#  (882, [67]),
#  (888, [19, 20]),
#  (894, [37]),
#  (895, [37]),
#  (897, [38]),
#  (898, [38]),
#  (899, [38]),
#  (900, [37]),
#  (903, [12]),
#  (908, [72]),
#  (909, [88]),
#  (910, [87]),
#  (912, [76]),
#  (914, [85]),
#  (921, [11]),
#  (926, [39]),
#  (928, [12]),
#  (929, [34]),
#  (930, [34]),
#  (932, [33]),
#  (938, [41]),
#  (939, [34]),
#  (941, [42]),
#  (944, [48]),
#  (945, [77]),
#  (954, [12, 33]),
#  (955, [33]),
#  (956, [34]),
#  (957, [34]),
#  (958, [34]),
#  (959, [77]),
#  (960, [77]),
#  (961, [76]),
#  (962, [38]),
#  (965, [12]),
#  (975, [33]),
#  (977, [11, 34]),
#  (982, [34, 76]),
#  (986, [32]),
#  (987, [71]),
#  (991, [12]),
#  (996, [34, 40]),
#  (997, [34]),
#  (998, [33]),
#  (1000, [78]),
#  (1003, [86]),
#  (1012, [34]),
#  (1013, [34]),
#  (1014, [45]),
#  (1019, [111]),
#  (1020, [34, 83]),
#  (1021, [83]),
#  (1024, [34]),
#  (1026, [37]),
#  (1029, [33]),
#  (1034, [34]),
#  (1037, [34]),
#  (1039, [11, 44]),
#  (1040, [38]),
#  (1043, [37]),
#  (1044, [37]),
#  (1045, [38]),
#  (1046, [38]),
#  (1053, [38]),
#  (1056, [37, 73]),
#  (1060, [12]),
#  (1067, [12]),
#  (1068, [100]),
#  (1069, [100]),
#  (1072, [37]),
#  (1076, [12]),
#  (1077, [34]),
#  (1081, [34]),
#  (1082, [34]),
#  (1083, [34]),
#  (1086, [34]),
#  (1087, [100]),
#  (1089, [34]),
#  (1090, [99]),
#  (1092, [95]),
#  (1093, [100]),
#  (1094, [100]),
#  (1106, [11]),
#  (1113, [12]),
#  (1124, [101]),
#  (1128, [52]),
#  (1133, [33]),
#  (1139, [73]),
#  (1142, [84]),
#  (1143, [83]),
#  (1144, [83]),
#  (1146, [78]),
#  (1149, [62]),
#  (1150, [12]),
